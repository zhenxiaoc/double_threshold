# %% [markdown]
# # 01 Dataset audit
#
# Search + access audit. No accessible dataset passes the hard gates; see `docs/dataset_search.md` and `docs/data_access_blockers.md`.

# %%
import sys; sys.path.insert(0, '../src')
import numpy as np, pandas as pd
from path_welfare.config import Config
from path_welfare.data_search import scorecard, CANDIDATES
sc = scorecard()
pd.DataFrame(sc)
