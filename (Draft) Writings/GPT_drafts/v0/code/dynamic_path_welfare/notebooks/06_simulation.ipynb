# %% [markdown]
# # 06 Monte Carlo
#
# Coverage / length / bias across DGPs. The conditional sieve interval under-covers; the participant bootstrap is the recommended interval.

# %%
import sys; sys.path.insert(0, '../src')
import numpy as np, pandas as pd
from path_welfare.config import Config
from path_welfare.simulation import run_mc
r = run_mc('dgp1', 1000, 40, seed=1, K=8, n_jobs=4)
{k: r['aggregate'][k] for k in ['V11_true','cov95','se_ratio','median_len95_sd','fail_rate']}
